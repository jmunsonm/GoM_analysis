# %% [markdown]
# rerun on 2021-12-07 after correcting for salinity of media samples

# %%
import pandas as pd
from pandas import DataFrame
import os
import sys
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.show()
import glob

os.chdir("/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/O2_consumption/")
outdir=('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/O2_consumption/')

# %%
# read the input file for O2 consumption and split it out by "Class". I might have to merge it with the genus statistiscs file or 
# open that file and use it to create a list of the genera for each class and do a couple of for i in list loops

# %%
in_df=pd.read_csv('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/GORG_recruitment/RNA_summaries/Prokka_Transcripts_percell_O2_percell_10SAG_genera_stats_biogeochemical_master_no2017.csv',
                 index_col=0)

in_df

with open("/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/Summary_files/Genera_with_10+_SAGs.txt") as file:
    tenGENs_list = [line.strip() for line in file]

ten_SAG_master=in_df[in_df['genus'].isin(tenGENs_list)]

ten_SAG_master

in_df=pd.read_csv('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/GORG_recruitment/RNA_summaries/Prokka_znormalized_Transcripts_percell_O2_percell_10SAG_genera_stats_biogeochemical_master_no2017.csv',
                 index_col=0)
norm_ten_SAG_master=in_df[in_df['genus'].isin(tenGENs_list)]

norm_ten_SAG_master
# Out:
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/envs/jacob_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (13622) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             genus      date  (-)-trans-carveol_dehydrogenase:limC:1.1.1.-  \
# 1      AAA164-E04  20181030                                           NaN
# 2      AAA164-E04  20190402                                           NaN
# 3      AAA164-E04  20190709                                           NaN
# 5      AAA536-G10  20181030                                           NaN
# 6      AAA536-G10  20190402                                           NaN
# ..            ...       ...                                           ...
# 634       UBA9926  20190402                                           NaN
# 635       UBA9926  20190709                                           NaN
# ...

# %%
Genus_tax=pd.read_csv('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/Summary_files/Genus_statistics.csv',
                     index_col=0)

classes=Genus_tax.Class.unique()

Genus_tax
# Out:
#           GTDB_genus                         full_GTDBtk_classification  \
# 0       Unclassified                                       Unclassified
# 1       Pelagibacter  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...
# 2               SW10  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 3    SCGC-AAA076-P13  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 4              D2472  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# ..               ...                                                ...
# 212          UBA6669  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 213           UBA721  d__Bacteria;p__Planctomycetota;c__Planctomycet...
# 214          UBA7359  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 215          UBA7446  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# 216           UBA974  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#      #_of_cells  genus_size_rank    Domain              Phyla  \
# ...

# %%
MYDIR = ("class_transcripts")
CHECK_FOLDER = os.path.isdir(MYDIR)

# If folder doesn't exist, then create it.
if not CHECK_FOLDER:
    os.makedirs(MYDIR)
    print("created folder : ", MYDIR)

else:
    print(MYDIR, "folder already exists.")
outdir=('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/O2_consumption/class_transcripts/')
# Out:
# class_transcripts folder already exists.

# %%
ten_SAG_master.dropna(how='all', axis=1, inplace=True)
ten_SAG_master.to_csv(outdir+'All_Genera_with_10+SAGs_Prokka_Transcripts_percell_O2_percell_Genus_stats_biogeochemical_master_no2017.csv')

for i in classes:
    i_df=pd.DataFrame()
    i_df=ten_SAG_master[ten_SAG_master['Class'] == i]
    i=str(i)
    i_df.dropna(how='all', axis=1, inplace=True)
    rows=i_df.shape[0]
    if rows > 0:
        i_df.to_csv(outdir+i+'_Genera_with_10+SAGs_Prokka_Transcripts_percell_O2_percell_Genus_stats_biogeochemical_master_no2017.csv')
    
   # print(i)
i_df
# Out:
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/envs/jacob_env/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/envs/jacob_env/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/envs/jacob_env/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
norm_ten_SAG_master.dropna(how='all', axis=1, inplace=True)
norm_ten_SAG_master.to_csv(outdir+'All_Genera_with_10+SAGs_Prokka_znormlized_Transcripts_percell_O2_percell_Genus_stats_biogeochemical_master_no2017.csv')

for i in classes:
    i_df=pd.DataFrame()
    i_df=norm_ten_SAG_master[norm_ten_SAG_master['Class'] == i]
    i=str(i)
    i_df.dropna(how='all', axis=1, inplace=True)
    rows=i_df.shape[0]
    if rows > 0:
        i_df.to_csv(outdir+i+'_Genera_with_10+SAGs_Prokka_znormalized_Transcripts_percell_O2_percell_Genus_stats_biogeochemical_master_no2017.csv')
    
   # print(i)
i_df
# Out:
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/envs/jacob_env/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/envs/jacob_env/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/envs/jacob_env/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
