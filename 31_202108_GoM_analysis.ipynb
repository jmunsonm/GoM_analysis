# %%
import pandas as pd
from pandas import DataFrame
import os
import sys
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.show()
import glob
import seaborn as sns

os.chdir('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/202108_GoM_resp/Assembly_and_FACS_files/')

outdir='/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/202108_GoM_resp/'
if os.path.isdir(outdir):
    print(outdir, "already exists.")
else:
    os.mkdir(outdir)
    print(outdir, "is created.")

images='/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_images/202108_GoM_resp_expts'
if os.path.isdir(images):
    print(images, "already exists.")
else:
    os.mkdir(images)
    print(images, "is created.")
    
matplotlib.__version__
# Out:
# /mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_analysis/202108_GoM_resp/ already exists.
# /mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/20210325_GoM_recluster_images/202108_GoM_resp_expts already exists.
# '3.3.3'

# %%
cols=['name', 'sample_collection_time', 'Predicted_respiration_rate_fmol_O2perhr', 'GTDB_classification', 'estimated_diameter', 'gate']
GoM_SAGs=pd.read_csv('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/Summary_files/202108_GoM_resp_decon_1cell_SAGs_master_predresp_rate.csv',
                    index_col=0, usecols=cols)


print(GoM_SAGs.columns)
GoM_RSG_SAGs=GoM_SAGs[GoM_SAGs['gate']=='Respiring cells (RSG-positive)']
GoM_RSG_SAGs.to_csv(outdir+'202108_GoM_resp_boxplot_data.csv')
GoM_SAGs

GoM_Syto_SAGs=GoM_SAGs[GoM_SAGs['gate']=='All prokaryotes (SYTO-9-positive)']
GoM_Syto_SAGs.to_csv(outdir+'202108_GoM_Syto9_boxplot_data.csv')
GoM_Syto_SAGs
# Out:
# Index(['GTDB_classification', 'estimated_diameter', 'gate',
#        'sample_collection_time', 'Predicted_respiration_rate_fmol_O2perhr'],
#       dtype='object')
#            GTDB_classification  estimated_diameter  \
# name
# AM-382-A10               D2472                0.23
# AM-382-A11              HIMB59                0.43
# AM-382-A14        Pelagibacter                0.42
# AM-382-A19              SGZJ01                0.43
# AM-382-A21        Luminiphilus                0.71
# ...                        ...                 ...
# AM-384-P17          Poseidonia                0.31
# AM-384-P18        Unclassified                0.14
# AM-384-P20         IMCC26134_A                0.78
# AM-384-P22            UBA10364                0.39
# AM-384-P23             UBA8337                0.38
#
#                                          gate sample_collection_time  \
# name
# AM-382-A10  All prokaryotes (SYTO-9-positive)                  Night
# ...
