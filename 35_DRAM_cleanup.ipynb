# %%
import pandas as pd
from pandas import DataFrame
import os
import sys
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.show()
import glob
import seaborn as sns
from collections import Counter
pd.set_option("display.max_rows", 10)

matplotlib.__version__
# Out:
# '3.1.0'

# %%
os.chdir('/mnt/scgc/simon/microg2p/Data/Decoupling_respiration_rates_contigs')

SAG_df=pd.read_csv('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/Summary_files/All_GoM_SAGs_1cell_20kb_decon_531normalized_predresp_rate_GTDBclass.csv',
                  index_col=0)

new_SAG_df=pd.read_csv('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/Summary_files/202108_GoM_resp_decon_1cell_SAGs_master_predresp_rate.csv',
                      index_col=0)


SAG_df.columns
# Out:
# Index(['X2', 'name', 'Plate', 'well_type', 'wga_cp', 'wgs_run_id',
#        'raw_read_count', 'final_assembly_length', 'max_contig_length',
#        'gc_content', 'checkM_estimated_completeness', 'total_CDS_count',
#        'hypothetical_cds_fraction', 'average_cds_length', 'number_multi_copy',
#        'checkM_classification', 'SSU_classification_1', 'SSU_classification_2',
#        'SSU_classification_3', 'notes', 'eventnum', 'well2', 'X531.40..488.',
#        'X572.27..488.', 'X692.40..488.', 'Trigger.Pulse.Width', 'SSC', 'FSC',
#        'estimated_diameter', 'PCA_analysis_Action', 'PCA_analysis_Note',
#        'Location', 'Sample_collection_Date', 'FACS_date', 'gate', 'depth..m.',
#        'sample', 'slope', 'intercept', 'normalized_531_value',
#        'Predicted_respiration_rate_fmol_O2perhr', 'lower_resp_bound',
#        'upper_resp_bound', 'SAG', 'GTDB_classification',
#        'GTDBtk_classification'],
#       dtype='object')

# %%
all_SAG_df=pd.concat([SAG_df,new_SAG_df], axis=0, ignore_index=True)
all_SAG_df
# Out:
# /mnt/scgc/scgc_nfs/opt/common/anaconda3a/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       FACS.date  FACS_date         FSC GTDB_classification  \
# 0           NaN   170412.0    2.147985        Pelagibacter
# 1           NaN   170412.0    3.236464         Hel1-33-131
# 2           NaN   170412.0    1.999698            IMCC9063
# 3           NaN   170412.0    4.689014          Thioglobus
# 4           NaN   170412.0    2.425642     SCGC-AAA076-P13
# ...         ...        ...         ...                 ...
# 6603   210928.0        NaN   12.255129          Poseidonia
# 6604   210928.0        NaN    1.437652        Unclassified
# ...

# %% [markdown]
# # I need to cleanup these dataframes so that they ahve the same columns and then generate a master file

# %%
clean_SAGs=SAG_df['name'].to_list()
clean_new_SAGs=new_SAG_df['name'].to_list()
all_clean_SAGs=clean_SAGs+clean_new_SAGs
print(len(clean_SAGs))
print(len(clean_new_SAGs))

len(all_clean_SAGs)

with open('/mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/Summary_files/Decoupling_respiration_rates_clean_SAGs.txt', 'w') as f:
    for item in all_clean_SAGs:
        f.write("%s\n" % item)
# Out:
# 5850
# 758

# %%
! find . -name '*contigs.fasta' | grep -v -f  /mnt/scgc/simon/microg2p/analyses/20210325_GoM_recluster/Summary_files/Decoupling_respiration_rates_clean_SAGs.txt | xargs rm

# %%
len(all_clean_SAGs)
# Out:
# 6608
